# %% [markdown]
# # Thrones2Vec

# %% [markdown]
# © Yuriy Guts, 2016

# %% [markdown]
# Using only the raw text of [A Song of Ice and Fire](https://en.wikipedia.org/wiki/A_Song_of_Ice_and_Fire), we'll derive and explore the semantic properties of its words.

# %% [markdown]
# ## Imports

# %%
from __future__ import absolute_import, division, print_function

# %%
import codecs
import glob
import logging
import multiprocessing
import os
import pprint
import re

# %%
import nltk
import gensim.models.word2vec as w2v
import sklearn.manifold
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# Out:
# c:\python\lib\site-packages\gensim\utils.py:1212: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# **Set up logging**

# %%
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %% [markdown]
# **Download NLTK tokenizer models (only the first time)**

# %%
nltk.download("punkt")
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\salzm\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\salzm\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ## Prepare Corpus

# %% [markdown]
# **Load books from files**

# %%
book_filenames = sorted(glob.glob("data/*.txt"))

# %%
print("Found books:")
book_filenames
# Out:
# Found books:
# ['data\\got1.txt',
#  'data\\got2.txt',
#  'data\\got3.txt',
#  'data\\got4.txt',
#  'data\\got5.txt']

# %% [markdown]
# **Combine the books into one string**

# %%
corpus_raw = u""
for book_filename in book_filenames:
    print("Reading '{0}'...".format(book_filename))
    with codecs.open(book_filename, "r", "utf-8") as book_file:
        corpus_raw += book_file.read()
    print("Corpus is now {0} characters long".format(len(corpus_raw)))
    print()
# Out:
# Reading 'data\got1.txt'...
# Corpus is now 1770659 characters long
#
# Reading 'data\got2.txt'...
# Corpus is now 4071041 characters long
#
# Reading 'data\got3.txt'...
# Corpus is now 6391405 characters long
#
# Reading 'data\got4.txt'...
# Corpus is now 8107945 characters long
#
# Reading 'data\got5.txt'...
# Corpus is now 9719485 characters long

# %% [markdown]
# **Split the corpus into sentences**

# %%
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

# %%
raw_sentences = tokenizer.tokenize(corpus_raw)

# %%
#convert into a list of words
#rtemove unnnecessary,, split into words, no hyphens
#list of words
def sentence_to_wordlist(raw):
    clean = re.sub("[^a-zA-Z]"," ", raw)
    words = clean.split()
    return words

# %%
#sentence where each word is tokenized
sentences = []
for raw_sentence in raw_sentences:
    if len(raw_sentence) > 0:
        sentences.append(sentence_to_wordlist(raw_sentence))

# %%
print(raw_sentences[5])
print(sentence_to_wordlist(raw_sentences[5]))
# Out:
# Heraldic crest by Virginia Norey.
# ['Heraldic', 'crest', 'by', 'Virginia', 'Norey']

# %%
token_count = sum([len(sentence) for sentence in sentences])
print("The book corpus contains {0:,} tokens".format(token_count))
# Out:
# The book corpus contains 1,818,103 tokens

# %% [markdown]
# ## Train Word2Vec

# %%
#ONCE we have vectors
#step 3 - build model
#3 main tasks that vectors help with
#DISTANCE, SIMILARITY, RANKING

# Dimensionality of the resulting word vectors.
#more dimensions, more computationally expensive to train
#but also more accurate
#more dimensions = more generalized
num_features = 300
# Minimum word count threshold.
min_word_count = 3

# Number of threads to run in parallel.
#more workers, faster we train
num_workers = multiprocessing.cpu_count()

# Context window length.
context_size = 7

# Downsample setting for frequent words.
#0 - 1e-5 is good for this
downsampling = 1e-3

# Seed for the RNG, to make the results reproducible.
#random number generator
#deterministic, good for debugging
seed = 1

# %%
thrones2vec = w2v.Word2Vec(
    sg=1,
    seed=seed,
    workers=num_workers,
    size=num_features,
    min_count=min_word_count,
    window=context_size,
    sample=downsampling
)

# %%
thrones2vec.build_vocab(sentences)
# Out:
# 2018-10-30 09:21:42,228 : INFO : collecting all words and their counts
# 2018-10-30 09:21:42,229 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2018-10-30 09:21:42,266 : INFO : PROGRESS: at sentence #10000, processed 140984 words, keeping 10280 word types
# 2018-10-30 09:21:42,319 : INFO : PROGRESS: at sentence #20000, processed 279730 words, keeping 13558 word types
# 2018-10-30 09:21:42,379 : INFO : PROGRESS: at sentence #30000, processed 420336 words, keeping 16598 word types
# 2018-10-30 09:21:42,432 : INFO : PROGRESS: at sentence #40000, processed 556581 words, keeping 18324 word types
# 2018-10-30 09:21:42,487 : INFO : PROGRESS: at sentence #50000, processed 686247 words, keeping 19714 word types
# 2018-10-30 09:21:42,548 : INFO : PROGRESS: at sentence #60000, processed 828497 words, keeping 21672 word types
# 2018-10-30 09:21:42,611 : INFO : PROGRESS: at sentence #70000, processed 973830 words, keeping 23093 word types
# 2018-10-30 09:21:42,671 : INFO : PROGRESS: at sentence #80000, processed 1114967 words, keeping 24252 word types
# 2018-10-30 09:21:42,723 : INFO : PROGRESS: at sentence #90000, processed 1260481 words, keeping 26007 word types
# 2018-10-30 09:21:42,780 : INFO : PROGRESS: at sentence #100000, processed 1393203 words, keeping 26884 word types
# 2018-10-30 09:21:42,861 : INFO : PROGRESS: at sentence #110000, processed 1532150 words, keeping 27809 word types
# 2018-10-30 09:21:42,934 : INFO : PROGRESS: at sentence #120000, processed 1680961 words, keeping 28486 word types
# 2018-10-30 09:21:43,000 : INFO : collected 29026 word types from a corpus of 1818103 raw words and 128868 sentences
# 2018-10-30 09:21:43,003 : INFO : Loading a fresh vocabulary
# 2018-10-30 09:21:43,190 : INFO : effective_min_count=3 retains 17277 unique words (59% of original 29026, drops 11749)
# 2018-10-30 09:21:43,191 : INFO : effective_min_count=3 leaves 1802699 word corpus (99% of original 1818103, drops 15404)
# 2018-10-30 09:21:43,281 : INFO : deleting the raw counts dictionary of 29026 items
# 2018-10-30 09:21:43,289 : INFO : sample=0.001 downsamples 50 most-common words
# 2018-10-30 09:21:43,292 : INFO : downsampling leaves estimated 1404424 word corpus (77.9% of prior 1802699)
# 2018-10-30 09:21:43,394 : INFO : estimated required memory for 17277 words and 300 dimensions: 50103300 bytes
# 2018-10-30 09:21:43,395 : INFO : resetting layer weights

# %%
print("Word2Vec vocabulary length:", len(thrones2vec.wv.vocab))
# Out:
# Word2Vec vocabulary length: 17277

# %% [markdown]
# **Start training, this might take a minute or two...**

# %%
thrones2vec.train(sentences, total_words=token_count, epochs=10)
# Out:
# 2018-10-30 09:21:47,489 : INFO : training model with 4 workers on 17277 vocabulary and 300 features, using sg=1 hs=0 sample=0.001 negative=5 window=7
# 2018-10-30 09:21:48,562 : INFO : EPOCH 1 - PROGRESS: at 9.34% words, 124132 words/s, in_qsize 8, out_qsize 0
# 2018-10-30 09:21:49,595 : INFO : EPOCH 1 - PROGRESS: at 20.31% words, 136424 words/s, in_qsize 8, out_qsize 0
# 2018-10-30 09:21:50,663 : INFO : EPOCH 1 - PROGRESS: at 31.30% words, 139372 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:21:51,954 : INFO : EPOCH 1 - PROGRESS: at 42.28% words, 133614 words/s, in_qsize 8, out_qsize 0
# 2018-10-30 09:21:53,029 : INFO : EPOCH 1 - PROGRESS: at 48.88% words, 124420 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:21:54,153 : INFO : EPOCH 1 - PROGRESS: at 59.86% words, 126666 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:21:55,171 : INFO : EPOCH 1 - PROGRESS: at 70.29% words, 128938 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:21:56,184 : INFO : EPOCH 1 - PROGRESS: at 79.63% words, 128998 words/s, in_qsize 8, out_qsize 0
# 2018-10-30 09:21:57,199 : INFO : EPOCH 1 - PROGRESS: at 90.06% words, 130525 words/s, in_qsize 8, out_qsize 0
# 2018-10-30 09:21:58,120 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-10-30 09:21:58,125 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-10-30 09:21:58,214 : INFO : EPOCH 1 - PROGRESS: at 99.45% words, 130437 words/s, in_qsize 1, out_qsize 1
# 2018-10-30 09:21:58,217 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-10-30 09:21:58,286 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-10-30 09:21:58,288 : INFO : EPOCH - 1 : training on 1818103 raw words (1404646 effective words) took 10.8s, 130242 effective words/s
# 2018-10-30 09:21:59,317 : INFO : EPOCH 2 - PROGRESS: at 8.24% words, 115391 words/s, in_qsize 8, out_qsize 1
# 2018-10-30 09:22:00,450 : INFO : EPOCH 2 - PROGRESS: at 18.11% words, 119125 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:22:01,487 : INFO : EPOCH 2 - PROGRESS: at 27.45% words, 121592 words/s, in_qsize 8, out_qsize 0
# 2018-10-30 09:22:02,502 : INFO : EPOCH 2 - PROGRESS: at 37.34% words, 125373 words/s, in_qsize 8, out_qsize 0
# 2018-10-30 09:22:03,587 : INFO : EPOCH 2 - PROGRESS: at 46.68% words, 124420 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:22:04,590 : INFO : EPOCH 2 - PROGRESS: at 56.57% words, 126742 words/s, in_qsize 8, out_qsize 0
# 2018-10-30 09:22:05,680 : INFO : EPOCH 2 - PROGRESS: at 65.90% words, 125844 words/s, in_qsize 8, out_qsize 0
# 2018-10-30 09:22:06,701 : INFO : EPOCH 2 - PROGRESS: at 75.79% words, 127057 words/s, in_qsize 8, out_qsize 0
# 2018-10-30 09:22:07,745 : INFO : EPOCH 2 - PROGRESS: at 85.11% words, 126852 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:22:08,831 : INFO : EPOCH 2 - PROGRESS: at 94.45% words, 126163 words/s, in_qsize 8, out_qsize 0
# 2018-10-30 09:22:09,205 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-10-30 09:22:09,329 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-10-30 09:22:09,347 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-10-30 09:22:09,365 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-10-30 09:22:09,367 : INFO : EPOCH - 2 : training on 1818103 raw words (1404371 effective words) took 11.1s, 127067 effective words/s
# 2018-10-30 09:22:10,387 : INFO : EPOCH 3 - PROGRESS: at 7.69% words, 106974 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:22:11,567 : INFO : EPOCH 3 - PROGRESS: at 18.11% words, 116181 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:22:12,616 : INFO : EPOCH 3 - PROGRESS: at 27.45% words, 119258 words/s, in_qsize 7, out_qsize 1
# 2018-10-30 09:22:13,667 : INFO : EPOCH 3 - PROGRESS: at 37.34% words, 122485 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:22:14,727 : INFO : EPOCH 3 - PROGRESS: at 46.68% words, 122691 words/s, in_qsize 8, out_qsize 0
# 2018-10-30 09:22:15,782 : INFO : EPOCH 3 - PROGRESS: at 56.57% words, 124257 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:22:16,902 : INFO : EPOCH 3 - PROGRESS: at 65.90% words, 123214 words/s, in_qsize 8, out_qsize 0
# 2018-10-30 09:22:17,914 : INFO : EPOCH 3 - PROGRESS: at 72.49% words, 119435 words/s, in_qsize 8, out_qsize 0
# 2018-10-30 09:22:19,001 : INFO : EPOCH 3 - PROGRESS: at 81.28% words, 118773 words/s, in_qsize 8, out_qsize 0
# 2018-10-30 09:22:20,055 : INFO : EPOCH 3 - PROGRESS: at 89.51% words, 117818 words/s, in_qsize 8, out_qsize 0
# 2018-10-30 09:22:21,058 : INFO : EPOCH 3 - PROGRESS: at 98.35% words, 118297 words/s, in_qsize 3, out_qsize 1
# 2018-10-30 09:22:21,060 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-10-30 09:22:21,163 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-10-30 09:22:21,223 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-10-30 09:22:21,237 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-10-30 09:22:21,241 : INFO : EPOCH - 3 : training on 1818103 raw words (1404763 effective words) took 11.9s, 118410 effective words/s
# 2018-10-30 09:22:22,287 : INFO : EPOCH 4 - PROGRESS: at 7.15% words, 99325 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:22:23,292 : INFO : EPOCH 4 - PROGRESS: at 16.48% words, 114940 words/s, in_qsize 8, out_qsize 0
# 2018-10-30 09:22:24,294 : INFO : EPOCH 4 - PROGRESS: at 24.71% words, 115131 words/s, in_qsize 8, out_qsize 0
# 2018-10-30 09:22:25,299 : INFO : EPOCH 4 - PROGRESS: at 33.50% words, 117136 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:22:26,328 : INFO : EPOCH 4 - PROGRESS: at 42.28% words, 117704 words/s, in_qsize 6, out_qsize 1
# 2018-10-30 09:22:27,337 : INFO : EPOCH 4 - PROGRESS: at 51.07% words, 118541 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:22:28,342 : INFO : EPOCH 4 - PROGRESS: at 59.86% words, 119214 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:22:29,347 : INFO : EPOCH 4 - PROGRESS: at 69.74% words, 121536 words/s, in_qsize 8, out_qsize 0
# 2018-10-30 09:22:30,351 : INFO : EPOCH 4 - PROGRESS: at 79.08% words, 122514 words/s, in_qsize 8, out_qsize 0
# 2018-10-30 09:22:31,405 : INFO : EPOCH 4 - PROGRESS: at 88.96% words, 123444 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:22:32,398 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-10-30 09:22:32,411 : INFO : EPOCH 4 - PROGRESS: at 98.90% words, 124771 words/s, in_qsize 2, out_qsize 1
# 2018-10-30 09:22:32,413 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-10-30 09:22:32,476 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-10-30 09:22:32,559 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-10-30 09:22:32,563 : INFO : EPOCH - 4 : training on 1818103 raw words (1404535 effective words) took 11.3s, 124445 effective words/s
# 2018-10-30 09:22:33,764 : INFO : EPOCH 5 - PROGRESS: at 9.34% words, 113258 words/s, in_qsize 8, out_qsize 0
# 2018-10-30 09:22:34,786 : INFO : EPOCH 5 - PROGRESS: at 19.21% words, 123696 words/s, in_qsize 8, out_qsize 0
# 2018-10-30 09:22:35,801 : INFO : EPOCH 5 - PROGRESS: at 28.55% words, 125634 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:22:36,844 : INFO : EPOCH 5 - PROGRESS: at 38.44% words, 127564 words/s, in_qsize 8, out_qsize 0
# 2018-10-30 09:22:37,866 : INFO : EPOCH 5 - PROGRESS: at 47.78% words, 127727 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:22:38,957 : INFO : EPOCH 5 - PROGRESS: at 57.67% words, 127708 words/s, in_qsize 8, out_qsize 0
# 2018-10-30 09:22:40,008 : INFO : EPOCH 5 - PROGRESS: at 65.90% words, 125227 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:22:41,129 : INFO : EPOCH 5 - PROGRESS: at 73.59% words, 121387 words/s, in_qsize 8, out_qsize 0
# 2018-10-30 09:22:42,177 : INFO : EPOCH 5 - PROGRESS: at 82.38% words, 120981 words/s, in_qsize 8, out_qsize 0
# 2018-10-30 09:22:43,261 : INFO : EPOCH 5 - PROGRESS: at 91.71% words, 120886 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:22:44,006 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-10-30 09:22:44,010 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-10-30 09:22:44,029 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-10-30 09:22:44,063 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-10-30 09:22:44,065 : INFO : EPOCH - 5 : training on 1818103 raw words (1404161 effective words) took 11.5s, 122533 effective words/s
# 2018-10-30 09:22:45,093 : INFO : EPOCH 6 - PROGRESS: at 7.69% words, 107812 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:22:46,268 : INFO : EPOCH 6 - PROGRESS: at 18.11% words, 116727 words/s, in_qsize 8, out_qsize 0
# 2018-10-30 09:22:47,286 : INFO : EPOCH 6 - PROGRESS: at 27.45% words, 120788 words/s, in_qsize 8, out_qsize 0
# 2018-10-30 09:22:48,439 : INFO : EPOCH 6 - PROGRESS: at 37.89% words, 122581 words/s, in_qsize 8, out_qsize 0
# 2018-10-30 09:22:49,445 : INFO : EPOCH 6 - PROGRESS: at 47.78% words, 125581 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:22:50,616 : INFO : EPOCH 6 - PROGRESS: at 57.67% words, 124401 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:22:51,665 : INFO : EPOCH 6 - PROGRESS: at 68.10% words, 126497 words/s, in_qsize 8, out_qsize 0
# 2018-10-30 09:22:52,755 : INFO : EPOCH 6 - PROGRESS: at 77.44% words, 125747 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:22:53,823 : INFO : EPOCH 6 - PROGRESS: at 87.31% words, 126168 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:22:54,899 : INFO : EPOCH 6 - PROGRESS: at 97.20% words, 126382 words/s, in_qsize 6, out_qsize 0
# 2018-10-30 09:22:55,075 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-10-30 09:22:55,079 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-10-30 09:22:55,137 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-10-30 09:22:55,186 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-10-30 09:22:55,188 : INFO : EPOCH - 6 : training on 1818103 raw words (1404948 effective words) took 11.1s, 126609 effective words/s
# 2018-10-30 09:22:56,228 : INFO : EPOCH 7 - PROGRESS: at 7.69% words, 105767 words/s, in_qsize 8, out_qsize 0
# 2018-10-30 09:22:57,250 : INFO : EPOCH 7 - PROGRESS: at 17.03% words, 116951 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:22:58,284 : INFO : EPOCH 7 - PROGRESS: at 25.26% words, 115198 words/s, in_qsize 6, out_qsize 1
# 2018-10-30 09:22:59,286 : INFO : EPOCH 7 - PROGRESS: at 34.05% words, 117346 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:23:00,299 : INFO : EPOCH 7 - PROGRESS: at 42.28% words, 116697 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:23:01,316 : INFO : EPOCH 7 - PROGRESS: at 51.07% words, 117532 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:23:02,318 : INFO : EPOCH 7 - PROGRESS: at 57.12% words, 112907 words/s, in_qsize 8, out_qsize 0
# 2018-10-30 09:23:03,392 : INFO : EPOCH 7 - PROGRESS: at 65.35% words, 112293 words/s, in_qsize 8, out_qsize 0
# 2018-10-30 09:23:04,422 : INFO : EPOCH 7 - PROGRESS: at 72.49% words, 110561 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:23:05,425 : INFO : EPOCH 7 - PROGRESS: at 77.99% words, 107263 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:23:06,461 : INFO : EPOCH 7 - PROGRESS: at 85.11% words, 106270 words/s, in_qsize 8, out_qsize 0
# 2018-10-30 09:23:07,488 : INFO : EPOCH 7 - PROGRESS: at 93.35% words, 106767 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:23:08,154 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-10-30 09:23:08,163 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-10-30 09:23:08,205 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-10-30 09:23:08,325 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-10-30 09:23:08,326 : INFO : EPOCH - 7 : training on 1818103 raw words (1404225 effective words) took 13.1s, 107036 effective words/s
# 2018-10-30 09:23:09,378 : INFO : EPOCH 8 - PROGRESS: at 7.69% words, 104094 words/s, in_qsize 8, out_qsize 0
# 2018-10-30 09:23:10,429 : INFO : EPOCH 8 - PROGRESS: at 15.93% words, 107214 words/s, in_qsize 8, out_qsize 0
# 2018-10-30 09:23:11,476 : INFO : EPOCH 8 - PROGRESS: at 24.71% words, 110783 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:23:12,490 : INFO : EPOCH 8 - PROGRESS: at 33.50% words, 113535 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:23:13,498 : INFO : EPOCH 8 - PROGRESS: at 42.28% words, 115268 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:23:14,499 : INFO : EPOCH 8 - PROGRESS: at 51.07% words, 116630 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:23:15,505 : INFO : EPOCH 8 - PROGRESS: at 59.86% words, 117535 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:23:16,516 : INFO : EPOCH 8 - PROGRESS: at 69.19% words, 119005 words/s, in_qsize 8, out_qsize 0
# 2018-10-30 09:23:17,516 : INFO : EPOCH 8 - PROGRESS: at 77.44% words, 118654 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:23:18,558 : INFO : EPOCH 8 - PROGRESS: at 86.76% words, 119349 words/s, in_qsize 8, out_qsize 0
# 2018-10-30 09:23:19,580 : INFO : EPOCH 8 - PROGRESS: at 95.55% words, 119411 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:23:19,917 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-10-30 09:23:19,940 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-10-30 09:23:20,004 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-10-30 09:23:20,080 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-10-30 09:23:20,082 : INFO : EPOCH - 8 : training on 1818103 raw words (1404532 effective words) took 11.7s, 119624 effective words/s
# 2018-10-30 09:23:21,114 : INFO : EPOCH 9 - PROGRESS: at 7.15% words, 98562 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:23:22,129 : INFO : EPOCH 9 - PROGRESS: at 15.93% words, 110158 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:23:23,139 : INFO : EPOCH 9 - PROGRESS: at 24.71% words, 114166 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:23:24,144 : INFO : EPOCH 9 - PROGRESS: at 32.40% words, 112623 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:23:25,181 : INFO : EPOCH 9 - PROGRESS: at 40.09% words, 110928 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:23:26,210 : INFO : EPOCH 9 - PROGRESS: at 48.88% words, 112458 words/s, in_qsize 8, out_qsize 0
# 2018-10-30 09:23:27,229 : INFO : EPOCH 9 - PROGRESS: at 57.67% words, 113719 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:23:28,233 : INFO : EPOCH 9 - PROGRESS: at 65.90% words, 113933 words/s, in_qsize 8, out_qsize 0
# 2018-10-30 09:23:29,267 : INFO : EPOCH 9 - PROGRESS: at 74.69% words, 114525 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:23:30,299 : INFO : EPOCH 9 - PROGRESS: at 83.46% words, 115016 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:23:31,312 : INFO : EPOCH 9 - PROGRESS: at 92.26% words, 115595 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:23:31,958 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-10-30 09:23:32,067 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-10-30 09:23:32,142 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-10-30 09:23:32,158 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-10-30 09:23:32,160 : INFO : EPOCH - 9 : training on 1818103 raw words (1404822 effective words) took 12.1s, 116451 effective words/s
# 2018-10-30 09:23:33,213 : INFO : EPOCH 10 - PROGRESS: at 7.15% words, 96900 words/s, in_qsize 8, out_qsize 0
# 2018-10-30 09:23:34,269 : INFO : EPOCH 10 - PROGRESS: at 16.48% words, 110666 words/s, in_qsize 8, out_qsize 1
# 2018-10-30 09:23:35,330 : INFO : EPOCH 10 - PROGRESS: at 25.26% words, 112699 words/s, in_qsize 6, out_qsize 1
# 2018-10-30 09:23:36,385 : INFO : EPOCH 10 - PROGRESS: at 34.05% words, 113876 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:23:37,461 : INFO : EPOCH 10 - PROGRESS: at 41.73% words, 111100 words/s, in_qsize 8, out_qsize 0
# 2018-10-30 09:23:38,530 : INFO : EPOCH 10 - PROGRESS: at 50.52% words, 111897 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:23:39,636 : INFO : EPOCH 10 - PROGRESS: at 59.31% words, 111930 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:23:40,653 : INFO : EPOCH 10 - PROGRESS: at 67.55% words, 112100 words/s, in_qsize 8, out_qsize 0
# 2018-10-30 09:23:41,708 : INFO : EPOCH 10 - PROGRESS: at 76.34% words, 112659 words/s, in_qsize 8, out_qsize 0
# 2018-10-30 09:23:42,771 : INFO : EPOCH 10 - PROGRESS: at 85.11% words, 112972 words/s, in_qsize 8, out_qsize 0
# 2018-10-30 09:23:43,820 : INFO : EPOCH 10 - PROGRESS: at 93.90% words, 113327 words/s, in_qsize 7, out_qsize 0
# 2018-10-30 09:23:44,427 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-10-30 09:23:44,458 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-10-30 09:23:44,534 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-10-30 09:23:44,540 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-10-30 09:23:44,543 : INFO : EPOCH - 10 : training on 1818103 raw words (1404914 effective words) took 12.4s, 113607 effective words/s
# 2018-10-30 09:23:44,545 : INFO : training on a 18181030 raw words (14045917 effective words) took 117.1s, 119994 effective words/s
# (14045917, 18181030)

# %% [markdown]
# **Save to file, can be useful later**

# %%
if not os.path.exists("trained"):
    os.makedirs("trained")

# %%
thrones2vec.save(os.path.join("trained", "thrones2vec.w2v"))
# Out:
# 2018-10-30 09:23:49,947 : INFO : saving Word2Vec object under trained\thrones2vec.w2v, separately None
# 2018-10-30 09:23:49,949 : INFO : not storing attribute vectors_norm
# 2018-10-30 09:23:49,951 : INFO : not storing attribute cum_table
# 2018-10-30 09:23:50,658 : INFO : saved trained\thrones2vec.w2v

# %% [markdown]
# ## Explore the trained model.

# %%
thrones2vec = w2v.Word2Vec.load(os.path.join("trained", "thrones2vec.w2v"))
# Out:
# 2018-10-30 09:23:52,337 : INFO : loading Word2Vec object from trained\thrones2vec.w2v
# 2018-10-30 09:23:52,747 : INFO : loading wv recursively from trained\thrones2vec.w2v.wv.* with mmap=None
# 2018-10-30 09:23:52,749 : INFO : setting ignored attribute vectors_norm to None
# 2018-10-30 09:23:52,749 : INFO : loading vocabulary recursively from trained\thrones2vec.w2v.vocabulary.* with mmap=None
# 2018-10-30 09:23:52,750 : INFO : loading trainables recursively from trained\thrones2vec.w2v.trainables.* with mmap=None
# 2018-10-30 09:23:52,751 : INFO : setting ignored attribute cum_table to None
# 2018-10-30 09:23:52,752 : INFO : loaded trained\thrones2vec.w2v

# %% [markdown]
# ### Compress the word vectors into 2D space and plot them

# %%
#my video - how to visualize a dataset easily
tsne = sklearn.manifold.TSNE(n_components=2, random_state=0)

# %%
all_word_vectors_matrix = thrones2vec.wv.syn0
# Out:
# c:\python\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `syn0` (Attribute will be removed in 4.0.0, use self.wv.vectors instead).
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# **Train t-SNE, this could take a minute or two...**

# %%
all_word_vectors_matrix_2d = tsne.fit_transform(all_word_vectors_matrix)

# %% [markdown]
# **Plot the big picture**

# %%
points = pd.DataFrame(
    [
        (word, coords[0], coords[1])
        for word, coords in [
            (word, all_word_vectors_matrix_2d[thrones2vec.wv.vocab[word].index])
            for word in thrones2vec.wv.vocab
        ]
    ],
    columns=["word", "x", "y"]
)

# %%
points.head(10)
# Out:
#         word          x          y
# 0       This -10.812779 -24.907185
# 1    edition -44.360657  34.713886
# 2        the   6.847619   5.518328
# 3   complete -14.405807   2.227196
# 4         of   4.071813   2.452708
# 5   original   0.081637  -0.500989
# 6  hardcover -43.436939  34.582745
# 7        ONE -47.123016  22.389534
# 8          A   3.487885  -9.899926
# 9         OF -50.172665  30.990356

# %%
sns.set_context("poster")

# %%
points.plot.scatter("x", "y", s=10, figsize=(20, 12))

# %% [markdown]
# **Zoom in to some interesting places**

# %%
def plot_region(x_bounds, y_bounds):
    slice = points[
        (x_bounds[0] <= points.x) &
        (points.x <= x_bounds[1]) & 
        (y_bounds[0] <= points.y) &
        (points.y <= y_bounds[1])
    ]
    
    ax = slice.plot.scatter("x", "y", s=35, figsize=(10, 8))
    for i, point in slice.iterrows():
        ax.text(point.x + 0.005, point.y + 0.005, point.word, fontsize=11)

# %% [markdown]
# **People related to Kingsguard ended up together**

# %%
plot_region(x_bounds=(4.0, 4.2), y_bounds=(-0.5, -0.1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-3606d96f6cad> in <module>
# ----> 1 plot_region(x_bounds=(4.0, 4.2), y_bounds=(-0.5, -0.1))
#
# <ipython-input-34-e43b5d403e4d> in plot_region(x_bounds, y_bounds)
#       7     ]
#       8
# ----> 9     ax = slice.plot.scatter("x", "y", s=35, figsize=(10, 8))
#      10     for i, point in slice.iterrows():
#      11         ax.text(point.x + 0.005, point.y + 0.005, point.word, fontsize=11)
#
# c:\python\lib\site-packages\pandas\plotting\_core.py in scatter(self, x, y, s, c, **kwds)
#    2853         axes : matplotlib.AxesSubplot or np.array of them
#    2854         """
# -> 2855         return self(kind='scatter', x=x, y=y, c=c, s=s, **kwds)
#    2856
#    2857     def hexbin(self, x, y, C=None, reduce_C_function=None, gridsize=None,
#
# c:\python\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2675                           fontsize=fontsize, colormap=colormap, table=table,
#    2676                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2677                           sort_columns=sort_columns, **kwds)
#    2678     __call__.__doc__ = plot_frame.__doc__
#    2679
#
# c:\python\lib\site-packages\pandas\plotting\_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1900                  yerr=yerr, xerr=xerr,
#    1901                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1902                  **kwds)
#    1903
#    1904
#
# c:\python\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1685         if isinstance(data, DataFrame):
#    1686             plot_obj = klass(data, x=x, y=y, subplots=subplots, ax=ax,
# -> 1687                              kind=kind, **kwds)
#    1688         else:
#    1689             raise ValueError("plot kind %r can only be used for data frames"
#
# c:\python\lib\site-packages\pandas\plotting\_core.py in __init__(self, data, x, y, s, c, **kwargs)
#     835             # the handling of this argument later
#     836             s = 20
# --> 837         super(ScatterPlot, self).__init__(data, x, y, s=s, **kwargs)
#     838         if is_integer(c) and not self.data.columns.holds_integer():
#     839             c = self.data.columns[c]
#
# c:\python\lib\site-packages\pandas\plotting\_core.py in __init__(self, data, x, y, **kwargs)
#     810             y = self.data.columns[y]
#     811         if len(self.data[x]._get_numeric_data()) == 0:
# --> 812             raise ValueError(self._kind + ' requires x column to be numeric')
#     813         if len(self.data[y]._get_numeric_data()) == 0:
#     814             raise ValueError(self._kind + ' requires y column to be numeric')
#
# ValueError: scatter requires x column to be numeric

# %% [markdown]
# **Food products are grouped nicely as well. Aerys (The Mad King) being close to "roasted" also looks sadly correct**

# %%
plot_region(x_bounds=(0, 1), y_bounds=(4, 4.5))

# %% [markdown]
# ### Explore semantic similarities between book characters

# %% [markdown]
# **Words closest to the given word**

# %%
thrones2vec.most_similar("Stark")
# Out:
# c:\python\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# 2018-10-30 10:17:09,857 : INFO : precomputing L2-norms of word weight vectors
# c:\python\lib\site-packages\gensim\matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int32 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('Eddard', 0.6494436860084534),
#  ('executed', 0.5295657515525818),
#  ('beheaded', 0.501014232635498),
#  ('absently', 0.49610885977745056),
#  ('Horseface', 0.4874773919582367),
#  ('Edrick', 0.4825233519077301),
#  ('boyhood', 0.48046183586120605),
#  ('Harlon', 0.4653658866882324),
#  ('ROSLIN', 0.4638351798057556),
#  ('brotherly', 0.46306586265563965)]

# %%
thrones2vec.most_similar("Aerys")
# Out:
# c:\python\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('Jaehaerys', 0.6441448926925659),
#  ('II', 0.6145937442779541),
#  ('Conciliator', 0.612036943435669),
#  ('Maekar', 0.5901579260826111),
#  ('Mad', 0.5869351029396057),
#  ('Unlikely', 0.569348156452179),
#  ('Unworthy', 0.5618863105773926),
#  ('V', 0.5519529581069946),
#  ('Rhaenyra', 0.5513732433319092),
#  ('appointment', 0.5508006811141968)]

# %%
thrones2vec.most_similar("direwolf")
# Out:
# c:\python\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('wolf', 0.5899975299835205),
#  ('SHAGGYDOG', 0.5495602488517761),
#  ('Ghost', 0.5450400114059448),
#  ('pup', 0.5400731563568115),
#  ('GHOST', 0.5390492677688599),
#  ('muzzle', 0.5073918700218201),
#  ('direwolves', 0.48724016547203064),
#  ('Rickon', 0.48399126529693604),
#  ('snarling', 0.48035430908203125),
#  ('Shaggydog', 0.4802272319793701)]

# %% [markdown]
# **Linear relationships between word pairs**

# %%
def nearest_similarity_cosmul(start1, end1, end2):
    similarities = thrones2vec.most_similar_cosmul(
        positive=[end2, start1],
        negative=[end1]
    )
    start2 = similarities[0][0]
    print("{start1} is related to {end1}, as {start2} is related to {end2}".format(**locals()))
    return start2

# %%
nearest_similarity_cosmul("Stark", "Winterfell", "Riverrun")
nearest_similarity_cosmul("Jaime", "sword", "wine")
nearest_similarity_cosmul("Arya", "Nymeria", "dragons")
# Out:
# Stark is related to Winterfell, as Tully is related to Riverrun
# Jaime is related to sword, as hippocras is related to wine
# Arya is related to Nymeria, as prophecies is related to dragons
# c:\python\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: Call to deprecated `most_similar_cosmul` (Method will be removed in 4.0.0, use self.wv.most_similar_cosmul() instead).
#   after removing the cwd from sys.path.
# 'prophecies'

# %% [markdown]
# ## 1. Wie ähnlich sind sich Jon und Ygritte?

# %%
thrones2vec.wv.similarity('Jon','Ygritte')
# Out:
# 0.5082483

# %% [markdown]
# ## 3. Welche 7 Wörter sind am ähnlichsten zu Lannister?

# %%
thrones2vec.wv.most_similar('Lannister', topn = 7)
# Out:
# [('pays', 0.5203514099121094),
#  ('debts', 0.4943835139274597),
#  ('downfall', 0.49389827251434326),
#  ('Kevan', 0.4796605110168457),
#  ('Jaime', 0.4735616445541382),
#  ('kinship', 0.46174293756484985),
#  ('Tywin', 0.46017691493034363)]

# %% [markdown]
# ## 4. Was ergibt: Stark + Winterfell – Dragons?

# %%
thrones2vec.wv.most_similar(positive=["Stark", "Winterfell"], negative=["Dragons"])
# Out:
# [('Eddard', 0.5428768992424011),
#  ('Torrhen', 0.4636513590812683),
#  ('Bolton', 0.45740413665771484),
#  ('Cerwyn', 0.4547737240791321),
#  ('executed', 0.45449167490005493),
#  ('ROSLIN', 0.45116379857063293),
#  ('Dreadfort', 0.44773244857788086),
#  ('Hornwood', 0.44528526067733765),
#  ('Helman', 0.43801578879356384),
#  ('Leobald', 0.4353256821632385)]

# %% [markdown]
# ## 5. Was passt nicht „Winterfell, Riverrun, Jaime“?

# %%
thrones2vec.wv.doesnt_match('Winterfell Riverrun Jaime'.split())
# Out:
# 'Jaime'

# %% [markdown]
# ## 6. Wie ähnlich sind sich folgende Sätze:
# Satz1: „Hodor That was all he ever said“
# Satz2: „Hold the door“

# %%
import pyemd
sentences = ["Hodor That was all he ever said","Hold the door"]
thrones2vec.wv.wmdistance(sentences[0], sentences[1])
# Out:
# 2018-10-30 10:17:22,916 : INFO : Removed 8 and 3 OOV words from document 1 and 2 (respectively).
# 2018-10-30 10:17:22,918 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2018-10-30 10:17:22,919 : INFO : built Dictionary(13 unique tokens: ['H', 'T', 'a', 'd', 'e']...) from 2 documents (total 33 corpus positions)
# 1.9370173191300333

# %% [markdown]
# ## 2. Wie sieht der Vektor aus zu Arryn?

# %%
thrones2vec.wv.similarity('Jon','Arryn')
# Out:
# 0.2744561
